# %% [markdown]
# Installing dependencies

# %%
# !pip install stable-baselines3[extra]
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: stable-baselines3[extra] in /home/kuba/.local/lib/python3.10/site-packages (1.8.0)
# Requirement already satisfied: importlib-metadata~=4.13 in /home/kuba/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (4.13.0)
# Requirement already satisfied: numpy in /home/kuba/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (1.24.3)
# Requirement already satisfied: gym==0.21 in /home/kuba/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (0.21.0)
# Requirement already satisfied: cloudpickle in /home/kuba/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (2.2.1)
# Requirement already satisfied: pandas in /home/kuba/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (2.0.1)
# Requirement already satisfied: matplotlib in /home/kuba/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (3.7.1)
# Requirement already satisfied: torch>=1.11 in /home/kuba/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: rich in /home/kuba/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (13.3.5)
# Requirement already satisfied: pillow in /usr/lib/python3/dist-packages (from stable-baselines3[extra]) (9.0.1)
# Requirement already satisfied: ale-py==0.7.4 in /home/kuba/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (0.7.4)
# Requirement already satisfied: autorom[accept-rom-license]~=0.6.0 in /home/kuba/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: tqdm in /home/kuba/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (4.65.0)
# Requirement already satisfied: tensorboard>=2.9.1 in /home/kuba/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (2.12.2)
# Requirement already satisfied: psutil in /home/kuba/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (5.9.5)
# Requirement already satisfied: opencv-python in /home/kuba/.local/lib/python3.10/site-packages (from stable-baselines3[extra]) (4.7.0.72)
# Requirement already satisfied: importlib-resources in /home/kuba/.local/lib/python3.10/site-packages (from ale-py==0.7.4->stable-baselines3[extra]) (5.12.0)
# Requirement already satisfied: requests in /home/kuba/.local/lib/python3.10/site-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2.29.0)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (8.0.3)
# Requirement already satisfied: AutoROM.accept-rom-license in /home/kuba/.local/lib/python3.10/site-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: zipp>=0.5 in /usr/lib/python3/dist-packages (from importlib-metadata~=4.13->stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: absl-py>=0.4 in /home/kuba/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/kuba/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.17.3)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/kuba/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.3.2)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/lib/python3/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (59.6.0)
# Requirement already satisfied: wheel>=0.26 in /usr/lib/python3/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.37.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/kuba/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: protobuf>=3.19.6 in /home/kuba/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (4.22.3)
# Requirement already satisfied: markdown>=2.6.8 in /home/kuba/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/kuba/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.0)
# Requirement already satisfied: grpcio>=1.48.2 in /home/kuba/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.54.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/kuba/.local/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.8.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/kuba/.local/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3[extra]) (11.7.99)
# Requirement already satisfied: jinja2 in /home/kuba/.local/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3[extra]) (3.1.2)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/kuba/.local/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3[extra]) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/kuba/.local/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3[extra]) (10.9.0.58)
# Requirement already satisfied: typing-extensions in /home/kuba/.local/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3[extra]) (4.5.0)
# Requirement already satisfied: triton==2.0.0 in /home/kuba/.local/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/kuba/.local/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3[extra]) (11.7.4.91)
# Requirement already satisfied: filelock in /home/kuba/.local/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3[extra]) (3.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/kuba/.local/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3[extra]) (11.7.99)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/kuba/.local/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3[extra]) (11.7.91)
# Requirement already satisfied: networkx in /home/kuba/.local/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3[extra]) (3.1)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/kuba/.local/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3[extra]) (2.14.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/kuba/.local/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3[extra]) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/kuba/.local/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3[extra]) (8.5.0.96)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/kuba/.local/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3[extra]) (11.4.0.1)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/kuba/.local/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3[extra]) (10.2.10.91)
# Requirement already satisfied: sympy in /home/kuba/.local/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3[extra]) (1.11.1)
# Requirement already satisfied: cmake in /home/kuba/.local/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.11->stable-baselines3[extra]) (3.26.3)
# Requirement already satisfied: lit in /home/kuba/.local/lib/python3.10/site-packages (from triton==2.0.0->torch>=1.11->stable-baselines3[extra]) (16.0.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/kuba/.local/lib/python3.10/site-packages (from matplotlib->stable-baselines3[extra]) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/kuba/.local/lib/python3.10/site-packages (from matplotlib->stable-baselines3[extra]) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/kuba/.local/lib/python3.10/site-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/kuba/.local/lib/python3.10/site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/kuba/.local/lib/python3.10/site-packages (from matplotlib->stable-baselines3[extra]) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib->stable-baselines3[extra]) (2.4.7)
# Requirement already satisfied: contourpy>=1.0.1 in /home/kuba/.local/lib/python3.10/site-packages (from matplotlib->stable-baselines3[extra]) (1.0.7)
# Requirement already satisfied: pytz>=2020.1 in /home/kuba/.local/lib/python3.10/site-packages (from pandas->stable-baselines3[extra]) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/kuba/.local/lib/python3.10/site-packages (from pandas->stable-baselines3[extra]) (2023.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /home/kuba/.local/lib/python3.10/site-packages (from rich->stable-baselines3[extra]) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/kuba/.local/lib/python3.10/site-packages (from rich->stable-baselines3[extra]) (2.15.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/kuba/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (5.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/lib/python3/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/kuba/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/kuba/.local/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/kuba/.local/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /home/kuba/.local/lib/python3.10/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kuba/.local/lib/python3.10/site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/kuba/.local/lib/python3.10/site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/kuba/.local/lib/python3.10/site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/kuba/.local/lib/python3.10/site-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]) (1.26.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/kuba/.local/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /home/kuba/.local/lib/python3.10/site-packages (from sympy->torch>=1.11->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/kuba/.local/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.0)

# %% [markdown]
# Setting up enviroment

# %%
import os
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
enviroment_name = "CartPole-v0"
env = gym.make(enviroment_name)

# %%
episodes = 5
for episode in range(1, episodes + 1):
    state = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score += reward
    print("Episode {} Score {}".format(episode, score))
env.close()
# Out:
# Episode 1 Score 23.0
# Episode 2 Score 34.0
# Episode 3 Score 29.0
# Episode 4 Score 29.0
# Episode 5 Score 17.0

# %% [markdown]
# Train RL model

# %%
tf_log_path = os.path.join('Traning', 'Logs')

# %%
tf_log_path
# Out:
# 'Traning/Logs'

# %%
env = gym.make(enviroment_name) # create gym enviroment
env = DummyVecEnv([lambda: env])    # wrap env into DummyVec
model = PPO("MlpPolicy", env, verbose=1, tensorboard_log=tf_log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Traning/Logs/PPO_1
# -----------------------------
# | time/              |      |
# |    fps             | 1922 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1292        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009577846 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.00446    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.45        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0155     |
# |    value_loss           | 50.2        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1192       |
# |    iterations           | 3          |
# |    time_elapsed         | 5          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.00928521 |
# |    clip_fraction        | 0.065      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.661     |
# |    explained_variance   | 0.106      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 13.9       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0182    |
# |    value_loss           | 32.2       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1153        |
# |    iterations           | 4           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011952925 |
# |    clip_fraction        | 0.0942      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.627      |
# |    explained_variance   | 0.25        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.4        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.021      |
# |    value_loss           | 52.8        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1119         |
# |    iterations           | 5            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0056271767 |
# |    clip_fraction        | 0.0482       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.604       |
# |    explained_variance   | 0.319        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.9         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0133      |
# |    value_loss           | 61.2         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1100       |
# |    iterations           | 6          |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.00903234 |
# |    clip_fraction        | 0.0708     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.59      |
# |    explained_variance   | 0.577      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 14.2       |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0145    |
# |    value_loss           | 53.9       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1087         |
# |    iterations           | 7            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0049074357 |
# |    clip_fraction        | 0.0436       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.584       |
# |    explained_variance   | 0.648        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.62         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0109      |
# |    value_loss           | 46.2         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1080        |
# |    iterations           | 8           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.004185642 |
# |    clip_fraction        | 0.0295      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.567      |
# |    explained_variance   | 0.591       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.91        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00714    |
# |    value_loss           | 44.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1073        |
# |    iterations           | 9           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.006720384 |
# |    clip_fraction        | 0.0422      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.567      |
# |    explained_variance   | 0.5         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.69        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00562    |
# |    value_loss           | 32.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1071         |
# |    iterations           | 10           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0036088768 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.537       |
# |    explained_variance   | 0.59         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.884        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00129     |
# |    value_loss           | 14           |
# ------------------------------------------

# %% [markdown]
# Save na Reload model

# %%
PPO_path = os.path.join('Traning', "Saved_models", "PPO_Model_Cartpole")

# %%
model.save(PPO_path)

# %%
del model

# %%
model = PPO.load(PPO_path)

# %% [markdown]
# Evaluation

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# /home/kuba/.local/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (200.0, 0.0)

# %% [markdown]
# Test model

# %%
episodes = 5
for episode in range(1, episodes + 1):
    observation = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action, _states = model.predict(observation)     # Using model here
        observation, reward, done, info = env.step(action)
        score += reward
    print("Episode {} Score {}".format(episode, score))
env.close()
# Out:
# Episode 1 Score [12.]
# Episode 2 Score [10.]
# Episode 3 Score [10.]
# Episode 4 Score [10.]
# Episode 5 Score [10.]

# %%
obs = env.reset()

# %% [markdown]
# Callback on the traning stage

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join("Traning", "Saved_models")

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=200, verbose=1)
eval_callback = EvalCallback(env, 
                             callback_on_new_best=stop_callback,
                             eval_freq=10000,
                             best_model_save_path=save_path,
                             verbose=1)

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=tf_log_path)
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Using cpu device
# Logging to Traning/Logs/PPO_3
# -----------------------------
# | time/              |      |
# |    fps             | 1774 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1242        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010501511 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.685      |
# |    explained_variance   | -0.0052     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.02        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0204     |
# |    value_loss           | 48.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1114        |
# |    iterations           | 3           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010787249 |
# |    clip_fraction        | 0.077       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.66       |
# |    explained_variance   | 0.1         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.3        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0195     |
# |    value_loss           | 37.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1071        |
# |    iterations           | 4           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008228226 |
# |    clip_fraction        | 0.0886      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.626      |
# |    explained_variance   | 0.263       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.7        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0199     |
# |    value_loss           | 50.8        |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=174.80 +/- 20.87
# Episode length: 174.80 +/- 20.87
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 175         |
# |    mean_reward          | 175         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.007292238 |
# |    clip_fraction        | 0.0656      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.609      |
# |    explained_variance   | 0.306       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.1        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0171     |
# |    value_loss           | 54.8        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 1026  |
# |    iterations      | 5     |
# |    time_elapsed    | 9     |
# |    total_timesteps | 10240 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1028         |
# |    iterations           | 6            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0086758025 |
# |    clip_fraction        | 0.0761       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.59        |
# |    explained_variance   | 0.545        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.3         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0154      |
# |    value_loss           | 54.1         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1019        |
# |    iterations           | 7           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010900879 |
# |    clip_fraction        | 0.0891      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.574      |
# |    explained_variance   | 0.643       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.5        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 52.7        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 1019       |
# |    iterations           | 8          |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.00545231 |
# |    clip_fraction        | 0.058      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.581     |
# |    explained_variance   | 0.865      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.89       |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.00896   |
# |    value_loss           | 26.4       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1018         |
# |    iterations           | 9            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0050045648 |
# |    clip_fraction        | 0.0343       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.569       |
# |    explained_variance   | 0.167        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.686        |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0029      |
# |    value_loss           | 18.9         |
# ------------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.001075016 |
# |    clip_fraction        | 0.00083     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.559      |
# |    explained_variance   | 0.32        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.88        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00129    |
# |    value_loss           | 39.5        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 1001  |
# |    iterations      | 10    |
# |    time_elapsed    | 20    |
# |    total_timesteps | 20480 |
# ------------------------------

# %% [markdown]
# Changing Policies

# %%
net_architecture = [dict(pi=[128,128,128,128], # custom actor new neural network 4 layers 128 units in each layer
                        vf=[128,128,128,128])] # value function 4 layers with 128 units

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=tf_log_path, policy_kwargs={'net_arch':net_architecture})
# Out:
# Using cpu device
# /home/kuba/.local/lib/python3.10/site-packages/stable_baselines3/common/policies.py:457: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Traning/Logs/PPO_5
# -----------------------------
# | time/              |      |
# |    fps             | 1203 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 849          |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0058346135 |
# |    clip_fraction        | 0.0717       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.508       |
# |    explained_variance   | 0.158        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.46         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00287     |
# |    value_loss           | 30.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 790         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008283647 |
# |    clip_fraction        | 0.0804      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.478      |
# |    explained_variance   | -0.137      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.241       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00422    |
# |    value_loss           | 1.13        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 759         |
# |    iterations           | 4           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008422873 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.464      |
# |    explained_variance   | 0.178       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.105       |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00451    |
# |    value_loss           | 0.716       |
# -----------------------------------------
# Eval num_timesteps=9040, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 9040        |
# | train/                  |             |
# |    approx_kl            | 0.005644112 |
# |    clip_fraction        | 0.0481      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.473      |
# |    explained_variance   | -0.175      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.085       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -4.16e-05   |
# |    value_loss           | 0.492       |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 689   |
# |    iterations      | 5     |
# |    time_elapsed    | 14    |
# |    total_timesteps | 10240 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 685          |
# |    iterations           | 6            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0018942264 |
# |    clip_fraction        | 0.0453       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.479       |
# |    explained_variance   | 0.0202       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0664       |
# |    n_updates            | 150          |
# |    policy_gradient_loss | 0.000321     |
# |    value_loss           | 0.351        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 694          |
# |    iterations           | 7            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0049029416 |
# |    clip_fraction        | 0.0436       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.447       |
# |    explained_variance   | -0.0315      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.068        |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00273     |
# |    value_loss           | 0.25         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 696        |
# |    iterations           | 8          |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.01459811 |
# |    clip_fraction        | 0.0887     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.472     |
# |    explained_variance   | 0.00581    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0847     |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.00669   |
# |    value_loss           | 0.152      |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 686          |
# |    iterations           | 9            |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0076695443 |
# |    clip_fraction        | 0.0641       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.49        |
# |    explained_variance   | 0.0463       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.325        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000279    |
# |    value_loss           | 5.2          |
# ------------------------------------------
# Eval num_timesteps=19040, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 19040       |
# | train/                  |             |
# |    approx_kl            | 0.008959058 |
# |    clip_fraction        | 0.0613      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.441      |
# |    explained_variance   | -0.016      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00344     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | 0.000269    |
# |    value_loss           | 0.0695      |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 667   |
# |    iterations      | 10    |
# |    time_elapsed    | 30    |
# |    total_timesteps | 20480 |
# ------------------------------

# %% [markdown]
# Using alternate algorithm

# %%
from stable_baselines3 import DQN

# %%
model = DQN("MlpPolicy", env, verbose=1, tensorboard_log=tf_log_path)
model.learn(total_timesteps=20000)
# Out:
# Using cpu device
# Logging to Traning/Logs/DQN_2
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 6288     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 73       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.911    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 7824     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 188      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.846    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 9086     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 324      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.812    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 9383     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 395      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.784    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 9692     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 455      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.755    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 9818     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 516      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.721    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 9901     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 588      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.677    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 9955     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 679      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.609    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 10333    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 824      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.528    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 10695    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 994      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.48     |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 10852    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1095     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.449    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 10755    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1161     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.416    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 10755    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1230     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.39     |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 10714    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1285     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.345    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 10758    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1378     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.314    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 10777    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1445     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.288    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 10787    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1500     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.249    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 10847    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1581     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.212    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 10915    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1660     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.183    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 10943    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1721     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.155    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 10936    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1778     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.116    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 11000    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1862     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.079    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 11032    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1939     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 11070    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2030     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 11144    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2127     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 11155    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2214     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 11184    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2296     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 11261    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2412     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 11268    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2485     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 11282    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2561     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 11331    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2659     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 11343    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2730     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 11370    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2812     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 11446    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2969     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 11433    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3031     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 11500    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3155     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 11528    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3257     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 11555    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3351     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 11578    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3438     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 11583    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3500     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 11619    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3617     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 11645    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3717     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 11710    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3864     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 11753    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3986     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 11740    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4058     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 11749    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4140     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 11763    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4255     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 11768    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4326     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 11776    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4451     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 11779    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4522     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 11777    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4603     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 11783    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4693     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 11783    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4764     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 11792    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4847     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 11783    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4897     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 11808    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5020     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 11847    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5165     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 11837    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5244     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 11832    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5297     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 11843    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5398     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 11832    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5471     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 11844    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5569     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 11857    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5685     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 11869    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5768     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 11847    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5859     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 11844    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5935     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 11847    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6030     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 11855    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6107     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 11847    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6188     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 11846    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6251     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 11854    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6354     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 11851    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6416     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 11848    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6505     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 11868    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6614     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 11848    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6665     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 11575    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6787     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 11399    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6867     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 11299    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6942     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 11070    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7012     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 11021    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7083     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 11016    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7185     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 11030    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7275     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 11046    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7372     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 11048    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7441     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 11056    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7530     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 11062    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7596     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 11064    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7705     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 11066    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7776     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 11070    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7867     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 11070    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 7945     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 11080    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8047     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 11089    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8156     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 11106    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8260     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 11108    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8331     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 11126    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8424     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 11131    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8494     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 11139    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8577     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 11147    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8673     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 11138    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8738     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 11150    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8822     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 11159    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8903     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 11124    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 8947     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 10991    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9039     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 10959    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9141     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 10953    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9221     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 10967    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9316     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 10950    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9384     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 10954    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9474     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 10955    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9613     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 10956    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9691     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 10972    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9815     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 10969    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9889     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 10974    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 9985     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 10984    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10107    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 10986    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10166    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 10996    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10251    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 10996    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10362    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 10997    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10440    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 11006    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10524    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 11011    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10605    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 11024    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10692    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 11029    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10780    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 11032    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10853    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 11035    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 10937    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 11045    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 11026    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 11055    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11117    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 11065    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11210    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 11063    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11287    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 11055    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11355    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 11054    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11417    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 11050    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11503    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 11047    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11635    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 11054    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11736    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 11044    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11813    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 11068    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11959    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 11071    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12030    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 11079    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12110    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 11091    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12224    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 11095    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12312    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 11088    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12405    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 11091    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12496    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 11107    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12659    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 11093    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12743    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 11093    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12853    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 11101    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 12932    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 11109    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13020    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 11104    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13068    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 11103    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13143    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 11091    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13211    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 11086    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13306    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 10943    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13475    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 10924    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 13569    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# ...
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 10943    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 15536    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 704      |
# |    fps              | 10937    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 15597    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 708      |
# |    fps              | 10939    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 15692    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 712      |
# |    fps              | 10943    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 15803    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 716      |
# |    fps              | 10936    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 15900    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 10939    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16018    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 724      |
# |    fps              | 10950    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16129    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 728      |
# |    fps              | 10944    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16203    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 732      |
# |    fps              | 10951    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16290    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 736      |
# |    fps              | 10953    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16359    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 10938    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16438    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 744      |
# |    fps              | 10933    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16506    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 748      |
# |    fps              | 10937    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16577    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 752      |
# |    fps              | 10936    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16642    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 756      |
# |    fps              | 10942    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16743    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 10859    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16831    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 764      |
# |    fps              | 10838    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16921    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 768      |
# |    fps              | 10824    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 16975    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 772      |
# |    fps              | 10823    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17075    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 776      |
# |    fps              | 10829    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17168    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 10717    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17263    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 784      |
# |    fps              | 10583    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17346    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 788      |
# |    fps              | 10526    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17403    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 792      |
# |    fps              | 10487    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17512    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 796      |
# |    fps              | 10461    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17630    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 10465    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17695    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 804      |
# |    fps              | 10471    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17758    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 808      |
# |    fps              | 10481    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17840    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 812      |
# |    fps              | 10491    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 17960    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 816      |
# |    fps              | 10499    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18051    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 10503    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18126    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 824      |
# |    fps              | 10509    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18209    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 828      |
# |    fps              | 10521    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18312    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 832      |
# |    fps              | 10533    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18420    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 836      |
# |    fps              | 10539    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18526    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 10540    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18618    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 844      |
# |    fps              | 10545    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18702    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 848      |
# |    fps              | 10558    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18810    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 852      |
# |    fps              | 10559    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18877    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 856      |
# |    fps              | 10565    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 18956    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 10571    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19062    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 864      |
# |    fps              | 10503    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19201    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 868      |
# |    fps              | 10471    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19290    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 872      |
# |    fps              | 10461    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19386    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 876      |
# |    fps              | 10455    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19455    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 10459    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19526    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 884      |
# |    fps              | 10457    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19588    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 888      |
# |    fps              | 10453    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19693    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 892      |
# |    fps              | 10455    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19773    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 896      |
# |    fps              | 10459    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19857    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 900      |
# |    fps              | 10458    |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 19921    |
# ----------------------------------
